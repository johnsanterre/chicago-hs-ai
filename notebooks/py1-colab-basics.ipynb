# %% [markdown]
# # Lesson 1 — Colab: code in your browser
#
# Welcome. This page is a **notebook** — it's made of cells. This cell is text. The gray ones below are code.
#
# **To run a code cell:** click it, then press the ▶ button on its left (or press `Shift+Enter`).
#
# > **Working with your AI pair:** paste any error message into your AI assistant and ask *"explain this error like I'm new, then help me fix it — don't just give me the answer."*

# %% [markdown]
# ## 1. Make the computer say something
# Run this cell. The result appears right underneath it.

# %%
print("Hello from a Google computer")

# %% [markdown]
# ## 2. The computer is a calculator
# Run it. Then change the numbers and run it again — you can't break anything.

# %%
2026 - 2011   # how old is someone born in 2011?

# %%
print(7 * 6)
print(100 / 8)
print(2 ** 10)   # 2 to the power of 10

# %% [markdown]
# ## 3. Break something on purpose
# This cell has a mistake in it. Run it anyway and **read the red text** — it tells you exactly what stopped the computer.

# %%
print("this line is fine")
prnt("this one is not")

# %% [markdown]
# **Now fix it:** change `prnt` to `print` and run again. Congratulations — you just debugged your first program.
#
# Errors are reports, not judgments. You'll read hundreds of them, calmly.

# %% [markdown]
# ## 4. Your turn
# Make the cell below print **your name**. Then make it print your name and your school on two lines.

# %%
# your code here

# %% [markdown]
# ## 5. The build (from the lesson page)
# Print your name **100 times**. You haven't been taught how — that's on purpose.
# Ask your AI assistant, paste the code here, run it, and **make sure you understand every word** before moving on.
# Then change it to 1,000 times. What happens?

# %%
# ask your AI, paste, run, understand

# %% [markdown]
# ## Done
# Screenshot your 100-names cell and its output for the turn-in. See you in lesson 2.
