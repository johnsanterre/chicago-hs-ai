# %% [markdown]
# # Data 8 — Mini-project: investigate a real dataset
#
# The full pipeline, yours: **question → data → clean → analyze → chart → finding.**
#
# > **Working with your AI pair:** paste any error into your AI and ask *"explain this error like I'm new, then help me fix it — don't just give me the answer."*

# %% [markdown]
# ## The rules
# 1. **Question first** — write it before touching data. 2. **Cleaning log** — every change, listed. 3. **Honest charts** — claim titles, zero-based bars. 4. **The finding** — one paragraph, with a caveat. 5. **Sign for every line** — AI may help; you explain everything you keep.

# %% [markdown]
# ## Pick your data
# - A Chicago portal dataset (lesson 7 method)
# - Your own CSV about your life (screen time, games, practices)
# - The class's pooled course-1 bias tallies — a real dataset you helped make

# %%
# THE QUESTION I'M INVESTIGATING:
#

# %%
# load

# %%
# clean (log every change in comments)

# %%
# analyze

# %%
# chart

# %% [markdown]
# ## The finding
# One paragraph in a markdown cell: what you found, how confident you are, what would change your mind. This paragraph is the deliverable — the code exists to back it.
#
# **Turn-in:** the notebook, run top to bottom, twice, clean. That's the course.
