# %% [markdown]
# # LLM 8 — Mini-project: an AI helper for a real task
#
# Everything, aimed: a working AI helper for a task from your real life. Same method as every capstone: plan, pieces, sign for every line, runs twice.
#
# > **Working with your AI pair:** paste any error into your AI and ask *"explain this error like I'm new, then help me fix it — don't just give me the answer."*

# %% [markdown]
# ## Pick one (or invent at this size)
# - **The study buddy** — quizzes you from your notes file (docs + chat + structure)
# - **The club communicator** — turns messy announcements into clean JSON + a formatted message (structure + prompts)
# - **The homework explainer** — hint-first tutor with a strict never-just-answer system prompt (chat + evals)
# - **The schedule agent** — answers questions using 2+ lookup tools (agents)

# %%
# MY PLAN (before any code):
# what it does:
# who would use it:
# the pieces: 1.  2.  3.
# what could go wrong + my guard:

# %%
# piece 1

# %%
# piece 2

# %%
# the demo — full run, start to finish

# %% [markdown]
# ## Required in your demo
# 1. The system prompt (your design, explained). 2. One eval check from lesson 6 proving a property. 3. The cost line: total tokens used, printed. 4. A one-paragraph honesty note: what it does badly.
#
# **Turn-in:** notebook run twice clean + the honesty note. That's the course — and with it, the toolkit for the nonprofit practicum.
